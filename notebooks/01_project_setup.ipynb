# %% [markdown]
# # Stock Market Prediction — Nifty 500: Project Setup & Environment Verification
# ### Data Analytics Intern Project · PRD v1.1
#
# This notebook verifies your environment, installs dependencies, tests hardware availability (CPU/GPU for PyTorch), and validates that all project modules are runnable.

# %% [markdown]
# ## 1. Install & Verify Required Dependencies

# %%
# Install dependencies into the same Python environment as this notebook
import sys
from pathlib import Path

project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
print(f"Notebook Python: {sys.executable}")
# !{sys.executable} -m pip install -q -r "{project_root / 'requirements.txt'}"
# Out:
# Notebook Python: c:\ProgramData\anaconda3\python.exe
#   WARNING: The script websockets.exe is installed in 'C:\Users\priya\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts pwiz.exe and pwmigrate.exe are installed in 'C:\Users\priya\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script cffi-gen-src.exe is installed in 'C:\Users\priya\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts torchfrtrace.exe and torchrun.exe are installed in 'C:\Users\priya\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
# ...

# %% [markdown]
# ## 2. Check Python & PyTorch Hardware Acceleration

# %%
import sys
import torch
import sklearn
import xgboost
import statsmodels

print(f"Python Version:     {sys.version.split()[0]}")
print(f"PyTorch Version:    {torch.__version__}")
print(f"CUDA Available:     {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Device:         {torch.cuda.get_device_name(0)}")
else:
    print("Running on:         CPU (Optimized for standard laptops / cloud kernels)")
print(f"Scikit-Learn:       {sklearn.__version__}")
print(f"XGBoost:            {xgboost.__version__}")
print(f"Statsmodels:        {statsmodels.__version__}")
print("\nAll required packages are verified!")
# Out:
# Python Version:     3.13.5
# PyTorch Version:    2.13.0+cpu
# CUDA Available:     False
# Running on:         CPU (Optimized for standard laptops / cloud kernels)
# Scikit-Learn:       1.7.2
# XGBoost:            3.4.1
# Statsmodels:        0.14.4
#
# All required packages are verified!

# %% [markdown]
# ## 3. Project Directory Structure Verification

# %%
from pathlib import Path
import os

ROOT_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
expected_folders = ['data', 'src', 'models', 'notebooks', 'app', 'reports']

print(f"Project Root: {ROOT_DIR}\n")
for folder in expected_folders:
    p = ROOT_DIR / folder
    status = 'EXISTS' if p.exists() else 'MISSING'
    print(f" - {folder:12s} [{status}]")

print("\nSetup check complete. Proceed to `02_nifty500_prediction_pipeline.ipynb` or launch the Streamlit app!")
# Out:
# Project Root: c:\Users\priya\Documents\GitHub\Stock_Market_Prediction
#
#  - data         [EXISTS]
#  - src          [EXISTS]
#  - models       [EXISTS]
#  - notebooks    [EXISTS]
#  - app          [EXISTS]
#  - reports      [EXISTS]
#
# Setup check complete. Proceed to `02_nifty500_prediction_pipeline.ipynb` or launch the Streamlit app!

# %% [markdown]
# ## 4. How to Launch the Interactive Streamlit App
#
# From your terminal, run:
# ```bash
# streamlit run app/app.py
# ```
